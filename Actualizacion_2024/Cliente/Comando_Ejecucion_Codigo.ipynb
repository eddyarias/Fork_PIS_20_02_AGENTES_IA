# %%
# %run Cliente.py
# Out:
# El valor riesgo para: '[[38.7, 0.0, 663.0, 0.0, 12.94117647, 89.0, 12.8, 66.0, 0.0, -0.330874831, -78.43229134, 2.0, 21.0]]' es 'MEDIUM'.
# {'Output': 2}
#
# El valor riesgo para: '[[38.7, 0.0, 665.0, 0.0, 12.94117647, 89.0, 12.8, 66.0, 0.0, -0.330874831, -78.43229134, 2.0, 21.0]]' es 'MEDIUM'.
# {'Output': 2}
#
# El valor riesgo para: '[[35.8, 0.0, 668.0, 0.0, 12.94117647, 89.0, 12.8, 66.0, 0.0, -0.330874831, -78.43229134, 2.0, 21.0]]' es 'MEDIUM'.
# {'Output': 2}
#
# El valor riesgo para: '[[35.5, 0.0, 670.0, 0.0, 12.94117647, 89.0, 12.8, 66.0, 0.0, -0.330874831, -78.43229134, 2.0, 21.0]]' es 'MEDIUM'.
# {'Output': 2}
#
# El valor riesgo para: '[[35.5, 0.0, 664.0, 0.0, 12.94117647, 89.0, 12.8, 66.0, 0.0, -0.330874831, -78.43229134, 2.0, 21.0]]' es 'MEDIUM'.
# {'Output': 2}
#
# El valor riesgo para: '[[35.5, 0.0, 673.0, 0.0, 12.94117647, 89.0, 12.8, 66.0, 0.0, -0.330874831, -78.43229134, 2.0, 21.0]]' es 'MEDIUM'.
# {'Output': 2}
#
# ...
